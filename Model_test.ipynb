# %%
import tensorflow as tf
import numpy as np

import model
import images
import utils

import random

# %%
# Model validation
x_test, y_test, raw_names = images.read_traffic_light(False)# read the test set
idxs = [random.randint(0, x_test.shape[0] - 1) for _ in range(200)]

pics = []
labels = []
names = []

for i in idxs:
    pics.append(x_test[i])
    labels.append(y_test[i])
    names.append(raw_names[i])

x, _, _, result = model.get_model(is_train=False, keep_prob=1)

with tf.Session() as sess:
    saver = tf.train.Saver()
    saver.restore(sess, "./result/result.ckpt")#load the trainned model

    dists = result.eval(feed_dict={x: pics})

    right_count = 0
    for i in range(len(dists)):
        print(i)
        dist = dists[i]
        pred_result = np.argmax(dist) == labels[i]
        if pred_result:
            right_count += 1

        print("{}: {} is {}, result is {}".format(pred_result, names[i],
                                                  utils.get_traffic_name(labels[i]),
                                                  utils.get_traffic_name(np.argmax(dist))))

    print("accuracy is {}".format(right_count / len(dists)))
# Out:
# WARNING:tensorflow:From C:\Users\Administrator\Anaconda3\envs\TF\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From D:\traffic_light_classify\model.py:30: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From C:\Users\Administrator\Anaconda3\envs\TF\lib\site-packages\tensorflow\python\training\saver.py:1266: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# INFO:tensorflow:Restoring parameters from ./result/result.ckpt
# 0
# True: 2ed71396-75f3-4145-8cab-06bfcea3c082.jpg is red, result is red
# 1
# True: 4e3609cb-5f0b-4a94-bc41-4eeae9bd7a7d.jpg is red, result is red
# 2
# True: 1b8f4e59-c28c-48f6-a218-2568d847c7d0.jpg is red, result is red
# 3
# True: 7dd64ca8-8c30-46a9-8c14-cfa0f8250835.jpg is red, result is red
# 4
# True: 2b28edf6-66df-4f65-93c7-9c2213126098.jpg is red, result is red
# 5
# True: 4eb64365-0a9f-4940-b188-fbe06603aa56.jpg is red, result is red
# 6
# True: 4ec1539d-f864-4db8-840c-92cd44bdd89e.jpg is red, result is red
# 7
# True: 2e3ca39d-fd24-44f4-840f-907df193a8ea.jpg is red, result is red
# 8
# True: 4df1196e-da39-4e2e-b7dd-3698bebce92d.jpg is red, result is red
# 9
# True: 4c4d6c01-eae9-4f73-8bf4-b3dc537d8595.jpg is green, result is green
# 10
# True: 2baacc94-9757-432f-9965-c793b6debea5.jpg is green, result is green
# 11
# True: 6ee2f62f-f95e-4ed8-b1ae-64f1abe21cd8.jpg is green, result is green
# 12
# True: 3b62063c-b929-40a1-803d-d95cc5056ecf.jpg is red, result is red
# 13
# True: 07ce50ef-02f1-4b74-98ba-7839aaee8664.jpg is red, result is red
# 14
# True: 7aa81ad5-992b-41cc-8889-d1659b083c15.jpg is red, result is red
# 15
# True: 8a1bea72-2e7f-4de3-a09e-4c6a4ed18156.jpg is red, result is red
# 16
# True: 6f469b8c-303a-4999-88f1-4b0cece83966.jpg is green, result is green
# 17
# True: 4e3609cb-5f0b-4a94-bc41-4eeae9bd7a7d.jpg is red, result is red
# 18
# True: 7f0460ac-3136-419d-b67d-323f5af16f97.jpg is red, result is red
# 19
# True: 06ab17cd-888e-45de-9482-b432e23cea6a.jpg is green, result is green
# 20
# True: 2eb85c25-8e93-45e4-a6f1-f0074244422f.jpg is red, result is red
# 21
# True: 5d9e7424-c440-472a-9297-b410b59fe8b8.jpg is green, result is green
# 22
# True: 3f609861-dff1-4efa-a2b4-e8b2621eb936.jpg is red, result is red
# 23
# True: 3e2c81f8-a721-4a51-bfd1-3a0110fdfd01.jpg is green, result is green
# 24
# True: 5c70fc95-8d11-4255-ab89-3be6527fae78.jpg is green, result is green
# 25
# True: 3b3f3f10-bc87-42fe-9c34-f279aa2632de.jpg is red, result is red
# 26
# True: 4df1196e-da39-4e2e-b7dd-3698bebce92d.jpg is red, result is red
# 27
# True: 0beb5ae5-a4f1-4ab9-8bac-e2c7379f15e9.jpg is red, result is red
# 28
# True: 4c4cab65-0a6a-4169-8e89-f8f9dd1eef60.jpg is green, result is green
# 29
# True: 2c269acd-c0a0-4854-8956-9f85df300311.jpg is red, result is red
# 30
# True: 0f238957-63d2-434a-ab6b-e39169acb140.jpg is green, result is green
# 31
# True: 5b8336c2-f101-40db-8e56-0fa0911adc79.jpg is green, result is green
# 32
# True: 2e6a4c96-743e-45e7-9581-54c5736d0bcd.jpg is green, result is green
# 33
# True: 2b64ebbf-62a7-40ee-8b39-935d5035b354.jpg is red, result is red
# 34
# True: 6abe00c3-03d6-4f66-b859-1ffb3cc17255.jpg is red, result is red
# 35
# True: 4b43ba7d-f313-4675-be40-7c7dcc4f16bc.jpg is green, result is green
# 36
# True: 02ebf5b7-739f-4a80-a719-e0c465a5d390.jpg is red, result is red
# 37
# True: 5b8336c2-f101-40db-8e56-0fa0911adc79.jpg is green, result is green
# 38
# True: 7a97b20c-6bcf-4749-b615-f3294efa4f15.jpg is red, result is red
# 39
# True: 3b575eb3-8904-409e-bab1-672863cafdfd.jpg is yellow, result is yellow
# 40
# True: 6d5d4482-55c6-4f98-b1e8-6bb2639494a0.jpg is green, result is green
# 41
# True: 4f5f4ea6-f434-4c6b-a6a0-217f8dc0558a.jpg is green, result is green
# 42
# True: 6e001005-6d32-47da-a101-47d0c8a13c03.jpg is green, result is green
# 43
# True: 3ab8580b-8bc2-4ebf-ace1-1af04e5e7100.jpg is red, result is red
# 44
# True: 3e817dae-e718-49d2-b9b4-7c78497d0975.jpg is red, result is red
# 45
# True: 3c9ec9e8-48ed-47c6-99c1-06ff91c6f9b2.jpg is red, result is red
# 46
# True: 6d0a9dd1-5ab7-482c-89fa-f10e308e76d7.jpg is red, result is red
# 47
# True: 0ea9380e-646a-40ef-9caf-aa6df33b0a57.jpg is red, result is red
# 48
# True: 3b30ce17-0aaf-4863-a6ec-10bbb5022a88.jpg is red, result is red
# 49
# True: 1edf1e47-4610-4b63-940d-c25c3ecbe8a2.jpg is red, result is red
# 50
# True: 1ea45166-e65d-4982-bfd3-c2268522c634.jpg is red, result is red
# 51
# True: 2dc78fbd-bc56-41ef-9959-8d2013380183.jpg is red, result is red
# 52
# True: 1b7cde13-3680-4a6b-b5f9-2646c83beebd.jpg is red, result is red
# 53
# True: 1ce90251-b855-4976-bf9f-dd58f5a28e05.jpg is green, result is green
# 54
# True: 1f9f5108-a033-439d-8883-78ac8579e08b.jpg is red, result is red
# 55
# True: 4dd55818-25fd-4fd4-a1d4-a70c6077f721.jpg is red, result is red
# 56
# True: 2bedf825-ffcd-4197-9914-fe242a95e796.jpg is red, result is red
# 57
# True: 7c54c131-7ba3-48f1-a2ec-46100b02b971.jpg is red, result is red
# 58
# True: 5cdef306-b317-41ee-a26b-2f141edddcf1.jpg is red, result is red
# 59
# True: 6fe0a3f0-1a16-4652-b6a1-563bfcb5b416.jpg is green, result is green
# 60
# True: 7d3e8c90-5abd-43f1-828e-378af2741833.jpg is red, result is red
# 61
# True: 3c5f1eb0-01cc-47c5-816a-3292d2963497.jpg is red, result is red
# 62
# True: 3c5f1eb0-01cc-47c5-816a-3292d2963497.jpg is red, result is red
# 63
# True: 6a440667-533f-4a6d-a315-3bc4510bbd61.jpg is red, result is red
# 64
# True: 6d5d4482-55c6-4f98-b1e8-6bb2639494a0.jpg is green, result is green
# 65
# True: 2c40e75f-f129-468b-b3b7-adb3d35de70b.jpg is red, result is red
# 66
# True: 6c00fd43-e451-4468-8f0b-3d8e484ff332.jpg is green, result is green
# 67
# True: 3e0cac01-9d1b-4185-a687-48ef99862742.jpg is red, result is red
# 68
# True: 4eef1eb9-b799-46b7-9c5c-734bd79e011a.jpg is red, result is red
# 69
# True: 0d126c7a-0efa-4c79-88be-62ab9fe0551a.jpg is red, result is red
# 70
# True: 5e8456f1-5d9c-4ebf-8541-b07e4b8bdd1e.jpg is red, result is red
# 71
# True: 1c8f46d5-f18b-4ab9-b56a-2fb6c21a80c7.jpg is green, result is green
# 72
# True: 2a96ee29-88d9-435c-9758-44aa8b806212.jpg is green, result is green
# 73
# True: 3bf1f78f-4de4-41e9-9f52-f44daf44ddb7.jpg is red, result is red
# 74
# True: 5cdef306-b317-41ee-a26b-2f141edddcf1.jpg is red, result is red
# 75
# True: 0bbaa6ca-9f78-4cad-8c22-b95648fb90be.jpg is green, result is green
# 76
# True: 7cbbcd5f-567c-45ed-a806-24a9b7b25cbc.jpg is red, result is red
# 77
# True: 3bf1f78f-4de4-41e9-9f52-f44daf44ddb7.jpg is red, result is red
# 78
# True: 1f9f5108-a033-439d-8883-78ac8579e08b.jpg is red, result is red
# 79
# True: 0da38382-3b5b-4114-b54f-c706269e4a34.jpg is green, result is green
# 80
# True: 3a851882-17c9-46fc-8ea4-9fd68c27c6e5.jpg is red, result is red
# 81
# True: 7cbbcd5f-567c-45ed-a806-24a9b7b25cbc.jpg is red, result is red
# 82
# True: 4dddeaaf-d208-4609-ac0b-5ec7c5211697.jpg is green, result is green
# 83
# True: 7b8a9761-3854-4e05-9f6f-769b35966650.jpg is red, result is red
# 84
# True: 06cda0c4-bb90-4378-847f-50087095fce5.jpg is red, result is red
# 85
# True: 1c67083a-d0d9-40ec-89c2-e0205497b404.jpg is red, result is red
# 86
# True: 5d85a01e-208e-462c-a305-dc0882c41866.jpg is red, result is red
# 87
# True: 03df7425-fa62-48f7-9ae8-701c6fa849cf.jpg is red, result is red
# 88
# True: 1e3af45f-6fd3-4c8b-9c9e-f8e504b868d7.jpg is green, result is green
# 89
# True: 0cb705ab-5c6d-41f1-ad9b-c0a99812cf15.jpg is yellow, result is yellow
# 90
# True: 4eef1eb9-b799-46b7-9c5c-734bd79e011a.jpg is red, result is red
# 91
# True: 1bf45ec5-ff6d-4348-a95e-283e7f734da8.jpg is red, result is red
# 92
# True: 3a74fab1-033c-4f96-af11-12b94565114d.jpg is red, result is red
# 93
# True: 4c4cab65-0a6a-4169-8e89-f8f9dd1eef60.jpg is green, result is green
# 94
# True: 0ab8c5a1-a750-4137-ad0a-13e5da55bd09.jpg is green, result is green
# 95
# True: 1deaeb96-547a-458a-b7d2-9e19dedef40b.jpg is red, result is red
# 96
# True: 7e5c6807-f818-49bb-9f2a-933c02257b80.jpg is red, result is red
# 97
# True: 6b8f0934-893f-4eb6-a285-ca4be8a607f4.jpg is green, result is green
# 98
# True: 6d5d4482-55c6-4f98-b1e8-6bb2639494a0.jpg is green, result is green
# 99
# True: 6fe0a3f0-1a16-4652-b6a1-563bfcb5b416.jpg is green, result is green
# 100
# True: 2e6a4c96-743e-45e7-9581-54c5736d0bcd.jpg is green, result is green
# 101
# True: 00febbe1-a9ae-4b5f-b682-8ebfdae485a3.jpg is green, result is green
# 102
# False: 4ae6e803-45cb-4701-8685-9383d3f37696.jpg is green, result is red
# 103
# True: 3bae90d0-9746-4c34-b19b-4260df39c213.jpg is green, result is green
# 104
# True: 3c9ec9e8-48ed-47c6-99c1-06ff91c6f9b2.jpg is red, result is red
# 105
# True: 8a1bea72-2e7f-4de3-a09e-4c6a4ed18156.jpg is red, result is red
# 106
# True: 2a96ee29-88d9-435c-9758-44aa8b806212.jpg is green, result is green
# 107
# True: 1a2cc050-be2b-4468-b4f8-c17e2ef0a860.jpg is green, result is green
# 108
# True: 6d499104-3511-4896-a9eb-29b8b562fafe.jpg is green, result is green
# 109
# True: 6c147c22-f528-444e-b3c9-5f8dcad8e4c3.jpg is red, result is red
# 110
# True: 7f7eb1f0-b5c9-4b34-a6ca-5cdcd6eb3e33.jpg is red, result is red
# 111
# True: 0ea9380e-646a-40ef-9caf-aa6df33b0a57.jpg is red, result is red
# 112
# True: 2b02cdf9-9a90-4dfb-8a19-bb6f61d8e93b.jpg is green, result is green
# 113
# True: 6fca65e0-7ad2-4a88-a526-c3afd3cc7226.jpg is red, result is red
# 114
# True: 6fdcbf0b-22af-48cb-9aad-51ecb4c65fef.jpg is red, result is red
# 115
# True: 4d0ac541-2712-4b3b-b8bf-4c006b3f73ba.jpg is red, result is red
# 116
# True: 3cc9ce5e-32b2-4433-9df4-71573445b8df.jpg is red, result is red
# 117
# True: 5d6317bf-2f65-42f8-9ad5-6d0871a687c8.jpg is red, result is red
# 118
# True: 6c147c22-f528-444e-b3c9-5f8dcad8e4c3.jpg is red, result is red
# 119
# True: 3d3af7bc-b7a6-4d58-bff2-92aa8c6fee40.jpg is green, result is green
# 120
# True: 7a97b20c-6bcf-4749-b615-f3294efa4f15.jpg is red, result is red
# 121
# True: 4b600ea8-b565-4779-81f6-1ed50f0dcf54.jpg is green, result is green
# 122
# True: 3fc18ff9-798f-4ae6-a5a3-86612ff596f5.jpg is green, result is green
# 123
# True: 1bf3b8f8-f6cd-4416-ba1b-2805294a7762.jpg is red, result is red
# 124
# True: 1b5dfb53-c10f-40ef-89ea-75cffc99a328.jpg is green, result is green
# 125
# True: 3e2c81f8-a721-4a51-bfd1-3a0110fdfd01.jpg is green, result is green
# 126
# True: 5e9db72d-655b-460f-bacd-dbe86f1de3df.jpg is red, result is red
# 127
# True: 2bd45809-7d28-43d5-856c-f67c65163cc4.jpg is red, result is red
# 128
# True: 6a440667-533f-4a6d-a315-3bc4510bbd61.jpg is red, result is red
# 129
# True: 01ae3c3d-21c8-4711-853a-ba6fda9553bf.jpg is green, result is green
# 130
# True: 3c9ec9e8-48ed-47c6-99c1-06ff91c6f9b2.jpg is red, result is red
# 131
# True: 1ac8eb61-5ba9-42c6-a38a-9f6e5a8a966e.jpg is red, result is red
# 132
# True: 6d499104-3511-4896-a9eb-29b8b562fafe.jpg is green, result is green
# 133
# True: 4c026879-143c-4762-9a55-8e66657b6e3e.jpg is green, result is green
# 134
# True: 0f238957-63d2-434a-ab6b-e39169acb140.jpg is green, result is green
# 135
# True: 1d480174-ccab-4c2a-8856-6d283b262c28.jpg is green, result is green
# 136
# True: 7cbbcd5f-567c-45ed-a806-24a9b7b25cbc.jpg is red, result is red
# 137
# True: 0bf347bb-50fe-46ce-86f4-cdd42538c495.jpg is green, result is green
# 138
# True: 3fc15cf3-4b5b-4105-86b7-a76b5889bf2a.jpg is red, result is red
# 139
# True: 3f192617-88da-4b6a-bb5a-ad88e2a4da84.jpg is green, result is green
# 140
# True: 2bedf825-ffcd-4197-9914-fe242a95e796.jpg is red, result is red
# 141
# True: 5cdef306-b317-41ee-a26b-2f141edddcf1.jpg is red, result is red
# 142
# True: 1a1046fb-bcf4-4d57-a15f-b269de7dd587.jpg is red, result is red
# 143
# True: 1e3af45f-6fd3-4c8b-9c9e-f8e504b868d7.jpg is green, result is green
# 144
# True: 4a72013c-c774-4bf4-b835-c9ca7218dd27.jpg is green, result is green
# 145
# True: 3bf1f78f-4de4-41e9-9f52-f44daf44ddb7.jpg is red, result is red
# 146
# True: 8a239750-c74a-46a0-87cd-51d349f1daeb.jpg is red, result is red
# 147
# True: 5dd25b77-c117-4cca-85e9-9843e917e0f1.jpg is green, result is green
# 148
# True: 3a851882-17c9-46fc-8ea4-9fd68c27c6e5.jpg is red, result is red
# 149
# True: 0e470b16-71f2-471c-8b31-a21f5ab4d814.jpg is green, result is green
# 150
# True: 4e60085a-fa81-4993-b894-7f12b6e84341.jpg is green, result is green
# 151
# True: 8a1bea72-2e7f-4de3-a09e-4c6a4ed18156.jpg is red, result is red
# 152
# True: 06ab17cd-888e-45de-9482-b432e23cea6a.jpg is green, result is green
# 153
# True: 7dd1b792-7b2d-4eda-8c0a-848e16eeaa77.jpg is red, result is red
# 154
# True: 0bc2c699-227a-4ac8-a7f4-8944c210d885.jpg is red, result is red
# 155
# True: 7f0460ac-3136-419d-b67d-323f5af16f97.jpg is red, result is red
# 156
# True: 5ded21ec-054e-4cf9-ac58-abfb51b4cb5a.jpg is red, result is red
# 157
# True: 7b13c35e-095b-4e4c-b77a-6fdbe776d1b0.jpg is red, result is red
# 158
# True: 07ce50ef-02f1-4b74-98ba-7839aaee8664.jpg is red, result is red
# 159
# True: 8a058952-df77-4093-9546-70b999044118.jpg is red, result is red
# 160
# True: 1f9f5108-a033-439d-8883-78ac8579e08b.jpg is red, result is red
# 161
# True: 3c5f1eb0-01cc-47c5-816a-3292d2963497.jpg is red, result is red
# 162
# True: 0bbaa6ca-9f78-4cad-8c22-b95648fb90be.jpg is green, result is green
# 163
# True: 4abec626-fa60-467a-ae75-a7975c153b7c.jpg is red, result is red
# 164
# True: 0e41f866-a861-415a-b9de-0ed37472816d.jpg is green, result is green
# 165
# True: 7f0460ac-3136-419d-b67d-323f5af16f97.jpg is red, result is red
# 166
# True: 2dbda507-73fb-4b27-b68f-c397e0f7d286.jpg is red, result is red
# 167
# True: 4b43ba7d-f313-4675-be40-7c7dcc4f16bc.jpg is green, result is green
# 168
# True: 6f7ab313-eb53-45ce-a0a4-2f672f5b5b3e.jpg is green, result is green
# 169
# True: 6b0e3c45-f25d-4741-8dc1-80276f303b6b.jpg is red, result is red
# 170
# True: 4b53f9e8-602a-4b1a-bb9b-ffc4a481e704.jpg is red, result is red
# 171
# True: 7a66ed45-e1d7-45ee-9a19-89f88413da39.jpg is red, result is red
# 172
# True: 5ab0c6b7-074d-47c5-bd62-a482e9015768.jpg is red, result is red
# 173
# True: 7f7eb1f0-b5c9-4b34-a6ca-5cdcd6eb3e33.jpg is red, result is red
# 174
# True: 5e9db72d-655b-460f-bacd-dbe86f1de3df.jpg is red, result is red
# 175
# True: 0cbfc957-3c03-42dd-a9ac-8972f385f69a.jpg is red, result is red
# 176
# True: 1f21db86-71d3-494b-bac8-23a4f1ca9b87.jpg is red, result is red
# 177
# True: 1deaeb96-547a-458a-b7d2-9e19dedef40b.jpg is red, result is red
# 178
# True: 0f1f6fd9-d77e-4160-b5d7-d9b7185eb589.jpg is red, result is red
# 179
# True: 2ec8abdd-2f32-4c2f-a5d0-391cd6e4f172.jpg is green, result is green
# 180
# True: 0be91609-32ba-4b7b-b460-cc47dd62b740.jpg is green, result is green
# 181
# True: 0cc018a8-fe72-4d92-94ef-4ac527f2dc36.jpg is red, result is red
# 182
# True: 0beb5ae5-a4f1-4ab9-8bac-e2c7379f15e9.jpg is red, result is red
# 183
# True: 7d55eceb-635c-47cc-a217-14574a0a8971.jpg is red, result is red
# 184
# True: 3e57194b-71bc-4858-aff1-3120b2f7e75d.jpg is green, result is green
# 185
# True: 0be1ae67-241f-4980-903f-8e8916e1fb1d.jpg is red, result is red
# 186
# True: 3a851882-17c9-46fc-8ea4-9fd68c27c6e5.jpg is red, result is red
# 187
# True: 5af6aa3e-4022-4297-b996-122ad1dc7c96.jpg is red, result is red
# 188
# True: 4c4d6c01-eae9-4f73-8bf4-b3dc537d8595.jpg is green, result is green
# 189
# True: 3ff0d3d6-c616-4116-83c3-b0b35e1e29f0.jpg is green, result is green
# 190
# True: 1c67083a-d0d9-40ec-89c2-e0205497b404.jpg is red, result is red
# 191
# True: 4dddeaaf-d208-4609-ac0b-5ec7c5211697.jpg is green, result is green
# 192
# True: 2b4de47c-5421-43c9-9d57-25c958d2ac43.jpg is red, result is red
# 193
# True: 4e03bed1-8ca5-4667-a339-0d782e427c6e.jpg is red, result is red
# 194
# True: 3d444dce-d900-45aa-aac7-d1c6d54f6bba.jpg is green, result is green
# 195
# True: 6c73784a-bafa-476c-b43b-19d9f20e8965.jpg is green, result is green
# 196
# True: 6c73784a-bafa-476c-b43b-19d9f20e8965.jpg is green, result is green
# 197
# True: 0cc018a8-fe72-4d92-94ef-4ac527f2dc36.jpg is red, result is red
# 198
# True: 0ae63733-c453-42b2-89cf-e4a7877feda6.jpg is green, result is green
# 199
# True: 3fc18ff9-798f-4ae6-a5a3-86612ff596f5.jpg is green, result is green
# accuracy is 0.995
